# %%
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader.data as web 

now = datetime.now()

now
# Out:
# datetime.datetime(2018, 1, 23, 8, 25, 43, 36779)

# %%
now.year,now.month,now.day
# Out:
# (2018, 1, 20)

# %%
delta = datetime(2016,6,19) - datetime.now()
delta
# Out:
# datetime.timedelta(-581, 14370, 258383)

# %%
delta.seconds
# Out:
# 14370

# %%
stamp = datetime(2011,1,3)
print(stamp)
print(str(stamp))
print(stamp.strftime('%Y-%m-%d'))
# Out:
# 2011-01-03 00:00:00
# 2011-01-03 00:00:00
# 2011-01-03

# %%
value = '2011-01-03'
datetime.strptime(value,'%Y-%m-%d')
# Out:
# datetime.datetime(2011, 1, 3, 0, 0)

# %%
from dateutil.parser import parse

parse('2011-01-03',dayfirst = True)
# Out:
# datetime.datetime(2011, 3, 1, 0, 0)

# %%
dates = [datetime(2018,1,2),datetime(2018,1,4),datetime(2018,1,6),datetime(2018,1,8),datetime(2018,1,10),datetime(2018,1,12)]
ts = pd.Series(np.random.randn(6),index=dates)
ts
# Out:
# 2018-01-02   -0.390073
# 2018-01-04    0.335465
# 2018-01-06   -1.116576
# 2018-01-08   -1.753129
# 2018-01-10    0.653646
# 2018-01-12   -0.618066
# dtype: float64

# %%
ts + ts[::2]
# Out:
# 2018-01-02   -0.780146
# 2018-01-04         NaN
# 2018-01-06   -2.233152
# 2018-01-08         NaN
# 2018-01-10    1.307291
# 2018-01-12         NaN
# dtype: float64

# %%
ts['20180104']
# Out:
# 0.33546465068606157

# %%
longer_ts = pd.Series(np.random.randn(1000),index= pd.date_range('20150101',periods=1000))
longer_ts
# Out:
# 2015-01-01    0.868632
# 2015-01-02    0.187710
# 2015-01-03    0.901824
# 2015-01-04   -0.432838
# 2015-01-05    0.202665
# 2015-01-06   -0.903898
# 2015-01-07    1.681873
# 2015-01-08    2.304807
# 2015-01-09    1.660365
# 2015-01-10    0.203022
# 2015-01-11   -0.016786
# 2015-01-12    1.045183
# 2015-01-13   -2.649633
# 2015-01-14   -0.789981
# 2015-01-15   -0.536375
# 2015-01-16    1.246616
# 2015-01-17    1.133346
# 2015-01-18    0.269005
# 2015-01-19   -0.302138
# 2015-01-20    0.485429
# 2015-01-21   -0.817790
# 2015-01-22    0.486142
# 2015-01-23   -0.016920
# 2015-01-24   -0.591053
# 2015-01-25   -1.623986
# 2015-01-26    0.248272
# 2015-01-27    0.365137
# 2015-01-28    0.304931
# 2015-01-29   -1.887402
# 2015-01-30   -0.286910
#                 ...
# 2017-08-28    1.421784
# 2017-08-29   -0.002669
# 2017-08-30   -1.438821
# 2017-08-31   -0.119543
# 2017-09-01   -0.804900
# 2017-09-02   -0.402392
# 2017-09-03    1.719728
# 2017-09-04    0.362583
# 2017-09-05   -0.829872
# ...

# %%
longer_ts['2015-01']
# Out:
# 2015-01-01    0.868632
# 2015-01-02    0.187710
# 2015-01-03    0.901824
# 2015-01-04   -0.432838
# 2015-01-05    0.202665
# 2015-01-06   -0.903898
# 2015-01-07    1.681873
# 2015-01-08    2.304807
# 2015-01-09    1.660365
# 2015-01-10    0.203022
# 2015-01-11   -0.016786
# 2015-01-12    1.045183
# 2015-01-13   -2.649633
# 2015-01-14   -0.789981
# 2015-01-15   -0.536375
# 2015-01-16    1.246616
# 2015-01-17    1.133346
# 2015-01-18    0.269005
# 2015-01-19   -0.302138
# 2015-01-20    0.485429
# 2015-01-21   -0.817790
# 2015-01-22    0.486142
# 2015-01-23   -0.016920
# 2015-01-24   -0.591053
# 2015-01-25   -1.623986
# 2015-01-26    0.248272
# 2015-01-27    0.365137
# 2015-01-28    0.304931
# 2015-01-29   -1.887402
# 2015-01-30   -0.286910
# 2015-01-31   -0.086555
# Freq: D, dtype: float64

# %%
dates = pd.date_range('20150101',periods=100,freq='W-WED')
long_df = pd.DataFrame(np.random.randn(100,4),
                      index=dates,
                      columns = ['Colorado','Texas','New York','Ohio'])
long_df.ix['2015-05']
# Out:
#             Colorado     Texas  New York      Ohio
# 2015-05-06 -0.640230 -0.032371  0.517588 -0.722499
# 2015-05-13  0.393813  0.468628  1.269220  0.249531
# 2015-05-20 -0.690337 -0.104495 -0.250258  0.646608
# 2015-05-27  1.583053  0.771779  0.340675  0.540760

# %%
index = pd.date_range('4/1/2017','6/1/2017')
index
# Out:
# DatetimeIndex(['2017-04-01', '2017-04-02', '2017-04-03', '2017-04-04',
#                '2017-04-05', '2017-04-06', '2017-04-07', '2017-04-08',
#                '2017-04-09', '2017-04-10', '2017-04-11', '2017-04-12',
#                '2017-04-13', '2017-04-14', '2017-04-15', '2017-04-16',
#                '2017-04-17', '2017-04-18', '2017-04-19', '2017-04-20',
#                '2017-04-21', '2017-04-22', '2017-04-23', '2017-04-24',
#                '2017-04-25', '2017-04-26', '2017-04-27', '2017-04-28',
#                '2017-04-29', '2017-04-30', '2017-05-01', '2017-05-02',
#                '2017-05-03', '2017-05-04', '2017-05-05', '2017-05-06',
#                '2017-05-07', '2017-05-08', '2017-05-09', '2017-05-10',
#                '2017-05-11', '2017-05-12', '2017-05-13', '2017-05-14',
#                '2017-05-15', '2017-05-16', '2017-05-17', '2017-05-18',
#                '2017-05-19', '2017-05-20', '2017-05-21', '2017-05-22',
# ...

# %%
pd.date_range('1/1/2017','12/31/2017',freq='M')
# Out:
# DatetimeIndex(['2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
#                '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('1/1/2017','1/3/2017 23:59',freq='4h')
# Out:
# DatetimeIndex(['2017-01-01 00:00:00', '2017-01-01 04:00:00',
#                '2017-01-01 08:00:00', '2017-01-01 12:00:00',
#                '2017-01-01 16:00:00', '2017-01-01 20:00:00',
#                '2017-01-02 00:00:00', '2017-01-02 04:00:00',
#                '2017-01-02 08:00:00', '2017-01-02 12:00:00',
#                '2017-01-02 16:00:00', '2017-01-02 20:00:00',
#                '2017-01-03 00:00:00', '2017-01-03 04:00:00',
#                '2017-01-03 08:00:00', '2017-01-03 12:00:00',
#                '2017-01-03 16:00:00', '2017-01-03 20:00:00'],
#               dtype='datetime64[ns]', freq='4H')

# %%
ts = pd.Series(np.random.randn(20),
              index = pd.date_range('20000115',periods=20,freq='4d'))

# %%
ts
# Out:
# 2000-01-15   -0.973325
# 2000-01-19    2.693147
# 2000-01-23    2.759862
# 2000-01-27   -0.904965
# 2000-01-31    0.445882
# 2000-02-04    1.047477
# 2000-02-08   -2.000299
# 2000-02-12    1.164967
# 2000-02-16   -1.314956
# 2000-02-20    0.092878
# 2000-02-24   -1.164556
# 2000-02-28    1.176568
# 2000-03-03    0.868753
# 2000-03-07    1.779449
# 2000-03-11   -1.092273
# 2000-03-15    0.747844
# 2000-03-19   -0.705579
# 2000-03-23    0.101937
# 2000-03-27    0.483158
# 2000-03-31   -0.385632
# Freq: 4D, dtype: float64

# %%
ts.resample('M',how='mean')
# Out:
# C:\Users\wangxw\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   if __name__ == '__main__':
# 2000-01-31    0.804120
# 2000-02-29   -0.142560
# 2000-03-31    0.224707
# Freq: M, dtype: float64

# %% [markdown]
# 分组因子暴露 P358

# %%
from  numpy.random import rand
fac1,fac2,fac3 = rand(3,1000)
n = 1000

ticker_subset = np.random.permutation(n)
# 因子加权和以及噪声
port = pd.Series(0.7*fac1 - 1.2*fac2 + 0.3*fac3 + rand(1000),
                index = ticker_subset)
factors = pd.DataFrame({'f1':fac1,'f2':fac2,'f3':fac3},
                      index = ticker_subset)

# %%
port
# Out:
# 9      0.853145
# 223   -0.162689
# 188    1.090467
# 458    0.685791
# 99     0.867861
# 770    0.935666
# 187   -0.034446
# 655   -0.185891
# 327    0.388279
# 459    1.381214
# 237    0.246501
# 277    0.376036
# 387    0.480911
# 618    0.582048
# 304   -0.483836
# 681    0.076540
# 61     0.109519
# 46     0.382746
# 700    0.749123
# 925   -0.343236
# 326    0.151988
# 675   -0.527173
# 139    0.770678
# 2      0.449119
# 122    1.234780
# 877    0.499583
# 820   -0.003582
# 173   -0.374490
# 176    0.398841
# 261    0.106749
#          ...
# 669    0.918415
# 107    1.082131
# 37    -0.647707
# 456    0.961615
# 88     0.570458
# 695    0.084544
# 704    0.765402
# 736   -0.018695
# 225   -0.093390
# 806    0.735269
# 928   -0.823271
# 265    0.580372
# 169    0.484481
# 838   -0.717067
# 462   -0.114398
# 253    0.018418
# 602    0.399438
# 626    0.180003
# 825    1.132869
# 818    0.480254
# 729   -0.157591
# 772    0.561534
# 943    0.712200
# 440    1.119941
# ...

# %%
factors.corrwith(port)
# Out:
# f1    0.394103
# f2   -0.701473
# f3    0.150331
# dtype: float64

# %%
pd.ols(y=port,x=factors).beta
# Out:
# C:\Users\wangxw\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning: The pandas.stats.ols module is deprecated and will be removed in a future version. We refer to external packages like statsmodels, see some examples here: http://statsmodels.sourceforge.net/stable/regression.html
#   exec(code_obj, self.user_global_ns, self.user_ns)
# f1           0.716045
# f2          -1.249735
# f3           0.282332
# intercept    0.526683
# dtype: float64

# %%
data = web.get_data_yahoo('SPY','2017-01-01')
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  225.039993  225.830002  223.880005  225.240005  220.944565
# 2017-01-04  225.619995  226.750000  225.610001  226.580002  222.259018
# 2017-01-05  226.270004  226.580002  225.479996  226.399994  222.082443
# 2017-01-06  226.529999  227.750000  225.899994  227.210007  222.876999
# 2017-01-09  226.910004  227.070007  226.419998  226.460007  222.141312
# 2017-01-10  226.479996  227.449997  226.009995  226.460007  222.141312
# 2017-01-11  226.360001  227.100006  225.589996  227.100006  222.769089
# 2017-01-12  226.500000  226.750000  224.960007  226.529999  222.209961
# 2017-01-13  226.729996  227.399994  226.690002  227.050003  222.720047
# 2017-01-17  226.309998  226.779999  225.800003  226.250000  221.935287
# 2017-01-18  226.539993  226.800003  225.899994  226.750000  222.425766
# 2017-01-19  226.839996  227.000000  225.410004  225.910004  221.601791
# ...

# %%
px = data['Adj Close']
returns = px.pct_change()

def to_index(rets):
    index = (1+rets).cumprod()
    first_loc = max(index.notnull().argmax()-1,0)
    index.values[first_loc] = 1
    return index

def trend_signal(rets,lookback,lag):
    signal = pd.rolling_sum(rets,lookback,min_periods=lookback - 5)
    return signal.shift(lag)

# %%
signal = trend_signal(returns,100,3)
trade_friday = signal.resample('W-FRI').resample('B',fill_method='ffill')
trade_rets = trade_friday.shift(1)*returns
# to_index(trade_rets).plot()
# Out:
# C:\Users\wangxw\Anaconda3\lib\site-packages\ipykernel\__main__.py:11: FutureWarning: pd.rolling_sum is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=100,min_periods=95).sum()
# C:\Users\wangxw\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: .resample() is now a deferred operation
# use .resample(...).mean() instead of .resample(...)
#   from ipykernel import kernelapp as app
# C:\Users\wangxw\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: fill_method is deprecated to .resample()
# the new syntax is .resample(...).ffill()
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-3ec5c009eecf> in <module>()
#       2 trade_friday = signal.resample('W-FRI').resample('B',fill_method='ffill')
# ...

# %%
vol = pd.rolling_std(returns,1000,min_periods=50)*np.sqrt(100)
def sharpe(rets,ann=100):
    return rets.mean()/rets.std()*np.sqrt(ann)
# Out:
# C:\Users\wangxw\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(center=False,window=1000,min_periods=50).std()
#   if __name__ == '__main__':

# %%
trade_rets.groupby(pd.qcut(vol,4)).agg(sharpe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-030788bbffef> in <module>()
# ----> 1 trade_rets.groupby(pd.qcut(vol,4)).agg(sharpe)
#
# C:\Users\wangxw\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    3776         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3777                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 3778                        **kwargs)
#    3779
#    3780     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# C:\Users\wangxw\Anaconda3\lib\site-packages\pandas\core\groupby.py in groupby(obj, by, **kwds)
#    1425         raise TypeError('invalid type: %s' % type(obj))
#    1426
# -> 1427     return klass(obj, by, **kwds)
#    1428
#    1429
#
# ...

# %%
names = ['AAPL','GOOG','MSFT','GS']
px = web.get_data_yahoo(names,'2016-01-01','2017-12-31')['Adj Close']

# %%
# px = px.asfreq('B').fillna(method='pad')
rets = px.pct_change()
((1 + rets).cumprod()-1).plot()
plt.show()

# %%
def get_px(stock,start,end):
    return web.get_data_yahoo(stock,start,end)['Adj Close']
px = pd.DataFrame({n:get_px(n,'2016-01-01','2017-12-31') for n in names})

# %%
px
# Out:
#                   AAPL         GOOG          GS       MSFT
# Date
# 2015-12-31  101.339394   758.880005  175.263641  52.818901
# 2016-01-04  101.426033   741.840027  172.258820  52.171520
# 2016-01-05   98.884369   742.580017  169.292862  52.409531
# 2016-01-06   96.949242   743.619995  165.159958  51.457489
# 2016-01-07   92.857529   726.390015  160.083832  49.667664
# 2016-01-08   93.348541   714.469971  159.422531  49.819996
# 2016-01-11   94.860062   716.030029  161.163208  49.791431
# 2016-01-12   96.236794   726.070007  161.143784  50.248405
# 2016-01-13   93.762527   700.559998  154.608932  49.163086
# 2016-01-14   95.813171   714.719971  156.942795  50.562584
# 2016-01-15   93.512207   694.450012  151.322083  48.544266
# 2016-01-19   93.059715   701.789978  152.498734  48.134892
# 2016-01-20   93.184875   698.450012  149.513321  48.353859
# 2016-01-21   92.713127   706.590027  147.471207  48.058727
# 2016-01-22   97.642410   725.250000  152.537628  49.781910
# ...

# %%
rets = px.pct_change()
plt.figure(figsize=(12,8))
plt.plot((1 + rets).cumprod()-1)
plt.show()
